# %% [markdown]
# # LandSlideAI Model Server Setup
#
# This notebook sets up the Flask server to serve predictions from your U-Net model.

# %%
# !pip install flask flask-cors tensorflow h5py numpy werkzeug pyngrok

# %%
from pyngrok import ngrok

# Start ngrok
public_url = ngrok.connect(5000)
print(f'Public URL: {public_url}')

# %%
# Save the Flask server code
with open('colab_server.py', 'w') as f:
    f.write('''[Content of colab_server.py as shown above]''')

# %%
# !python colab_server.py
